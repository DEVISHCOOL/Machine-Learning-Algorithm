# %%
import pandas as pd
df=pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.isnull().sum() # the dataset contains some null values and needs to filtered and preprocessed for model fitting
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
m=df.fillna('Nan') #used to fill all the empty columns with Nan (Not a number)
m
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0          120.0       0.0  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1          132.0   0.00638  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2          133.0  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3          134.0  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121       140.0       0.0  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122       140.0  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123       140.0   0.00098  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124       140.0  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125       142.0  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.describe() # the central dependancy and deviation has been illustrated using this function to reduce the calculation for each and every numerical column
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.head() #first five rows
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail() #last five rows
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
z=df.corr(numeric_only=True) #to understand correlation between each rows

# %%
z
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.009433  0.072012 -0.093507 -0.033623
# FM        0.018777  0.009433  1.000000 -0.053226  0.009718  0.029901
# UC       -0.166570  0.072012 -0.053226  1.000000  0.190128 -0.006937
# DL       -0.126959 -0.093507  0.009718  0.190128  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.231103 -0.032691 -0.181161 -0.069361  0.008452
# MSTV     -0.170473  0.134168  0.017055  0.189406  0.410102  0.016163
# ALTV      0.210728 -0.271390 -0.011936 -0.227304 -0.186967 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))
sns.heatmap(z, annot=True)
plt.show()
#the heatmap is used to correlate each and every numeric_only column with each other
# it has a range of 0.2-1.0 with colour variation

# %%
sns.pairplot(df) #the pairplot is a coombination of histogram and scatterplot which provides more insights by plotting graphs

# %%
df.hist(figsize=(25,35),layout=(6,9))
# Out:
# array([[<Axes: title={'center': 'LB'}>, <Axes: title={'center': 'AC'}>,
#         <Axes: title={'center': 'FM'}>, <Axes: title={'center': 'UC'}>,
#         <Axes: title={'center': 'DL'}>, <Axes: title={'center': 'DS'}>,
#         <Axes: title={'center': 'DP'}>, <Axes: title={'center': 'ASTV'}>,
#         <Axes: title={'center': 'MSTV'}>],
#        [<Axes: title={'center': 'ALTV'}>,
#         <Axes: title={'center': 'MLTV'}>,
#         <Axes: title={'center': 'Width'}>,
#         <Axes: title={'center': 'Tendency'}>,
#         <Axes: title={'center': 'NSP'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >],
# ...

# %%
import numpy as np

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.shape
# Out:
# (2126, 14)

# %%
x=(df)

# %%
x
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency
# 0      0.5  43.000000   2.4   64.0  0.999926
# ...

# %%
y=(df.NSP)

# %%
y
# Out:
# 0       2.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
#           ...
# 2121    2.000000
# 2122    2.000000
# 2123    1.990464
# 2124    2.000000
# 2125    1.000000
# Name: NSP, Length: 2126, dtype: float64

# %%
#since there are no categorical values to match, we cannot implement plots such as pieplots or bar plots.

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
plt.boxplot(df['UC']) # outliers are idemtified in this column and can be neglected as they dont interfere with deviance of result
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x799f596b4990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x799f596b4510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x799f60523e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x799f5977c710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x799f594ae110>],
#  'means': []}

# %%
plt.boxplot(df['ASTV']) # outliers are idemtified in this column and can be neglected as they dont interfere with deviance of result
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x799f593247d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x799f59325ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x799f5933ab10>],
#  'medians': [<matplotlib.lines.Line2D at 0x799f593275d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x799f592a4050>],
#  'means': []}

# %%
 plt.boxplot(df['DL'])# Since the humbr of outleiers are high, it should be modified to not affect the result or corresponding variance
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x799f5910d450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x799f5910f490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x799f5910c850>],
#  'medians': [<matplotlib.lines.Line2D at 0x799f5910e210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x799f5910c0d0>],
#  'means': []}

# %%
 plt.boxplot(df['UC']) # outliers are idemtified in this column and can be neglected as they dont interfere with deviance of result
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x799f58e05350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x799f58e06650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x799f58e04b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x799f58e079d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x799f58e342d0>],
#  'means': []}

# %%
 plt.boxplot(df['FM']) # Since the humbr of outleiers are high, it should be modified to not affect the result or corresponding variance
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x799f58db2350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x799f58d61750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x799f6457c390>],
#  'medians': [<matplotlib.lines.Line2D at 0x799f58d62f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x799f58d63a90>],
#  'means': []}
