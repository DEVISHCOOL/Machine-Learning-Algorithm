# %%
import pandas as pd
df_train=pd.read_csv(r"/content/Titanic_train.csv")
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_test=pd.read_csv(r"/content/Titanic_test.csv")
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_train.fillna("NA", inplace=True)
# Out:
# /tmp/ipython-input-77-3384352108.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_train.fillna("NA", inplace=True)

# %%
df_test.fillna("NA", inplace=True)
# Out:
# /tmp/ipython-input-78-2714459128.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_test.fillna("NA", inplace=True)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    object
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 83.7+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    object
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         418 non-null    object
#  9   Cabin        418 non-null    object
#  10  Embarked     418 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 36.1+ KB

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass       SibSp       Parch
# count   418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    2.265550    0.447368    0.392344
# std     120.810458    0.841838    0.896760    0.981429
# min     892.000000    1.000000    0.000000    0.000000
# 25%     996.250000    1.000000    0.000000    0.000000
# 50%    1100.500000    3.000000    0.000000    0.000000
# 75%    1204.750000    3.000000    1.000000    0.000000
# max    1309.000000    3.000000    8.000000    9.000000

# %%
df_train=df_train.drop(['PassengerId','Name','Ticket','Cabin'], axis=1)

# %%
df_train
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female    NA      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df_test=df_test.drop(['PassengerId','Name','Ticket','Cabin'], axis=1)
df_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    male  34.5      0      0   7.8292        Q
# 1         3  female  47.0      1      0      7.0        S
# 2         2    male  62.0      0      0   9.6875        Q
# 3         3    male  27.0      0      0   8.6625        S
# 4         3  female  22.0      1      1  12.2875        S
# ..      ...     ...   ...    ...    ...      ...      ...
# 413       3    male    NA      0      0     8.05        S
# 414       1  female  39.0      0      0    108.9        C
# 415       3    male  38.5      0      0     7.25        S
# 416       3    male    NA      0      0     8.05        S
# 417       3    male    NA      1      1  22.3583        C
#
# [418 rows x 7 columns]

# %%
gender_map={
    'male':0,
    'female':1
}

# %%
df_train['Sex']=df_train['Sex'].map(gender_map)
df_train
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    0  22.0      1      0   7.2500        S
# 1           1       1    1  38.0      1      0  71.2833        C
# 2           1       3    1  26.0      0      0   7.9250        S
# 3           1       1    1  35.0      1      0  53.1000        S
# 4           0       3    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    0  27.0      0      0  13.0000        S
# 887         1       1    1  19.0      0      0  30.0000        S
# 888         0       3    1    NA      1      2  23.4500        S
# 889         1       1    0  26.0      0      0  30.0000        C
# 890         0       3    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df_test['Sex']=df_test['Sex'].map(gender_map)
df_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    0  34.5      0      0   7.8292        Q
# 1         3    1  47.0      1      0      7.0        S
# 2         2    0  62.0      0      0   9.6875        Q
# 3         3    0  27.0      0      0   8.6625        S
# 4         3    1  22.0      1      1  12.2875        S
# ..      ...  ...   ...    ...    ...      ...      ...
# 413       3    0    NA      0      0     8.05        S
# 414       1    1  39.0      0      0    108.9        C
# 415       3    0  38.5      0      0     7.25        S
# 416       3    0    NA      0      0     8.05        S
# 417       3    0    NA      1      1  22.3583        C
#
# [418 rows x 7 columns]

# %%
embarked_map={
    'S':0,
    'C':1,
    'Q':2
}

# %%
df_train['Embarked']=df_train['Embarked'].map(embarked_map)
df_train
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500       0.0
# 1           1       1    1  38.0      1      0  71.2833       1.0
# 2           1       3    1  26.0      0      0   7.9250       0.0
# 3           1       1    1  35.0      1      0  53.1000       0.0
# 4           0       3    0  35.0      0      0   8.0500       0.0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000       0.0
# 887         1       1    1  19.0      0      0  30.0000       0.0
# 888         0       3    1    NA      1      2  23.4500       0.0
# 889         1       1    0  26.0      0      0  30.0000       1.0
# 890         0       3    0  32.0      0      0   7.7500       2.0
#
# [891 rows x 8 columns]

# %%
df_test['Embarked']=df_test['Embarked'].map(embarked_map)
df_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         3    0  34.5      0      0   7.8292         2
# 1         3    1  47.0      1      0      7.0         0
# 2         2    0  62.0      0      0   9.6875         2
# 3         3    0  27.0      0      0   8.6625         0
# 4         3    1  22.0      1      1  12.2875         0
# ..      ...  ...   ...    ...    ...      ...       ...
# 413       3    0    NA      0      0     8.05         0
# 414       1    1  39.0      0      0    108.9         1
# 415       3    0  38.5      0      0     7.25         0
# 416       3    0    NA      0      0     8.05         0
# 417       3    0    NA      1      1  22.3583         1
#
# [418 rows x 7 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train.hist(figsize=(10,10), layout=(3,4))
# Out:
# array([[<Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>,
#         <Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'SibSp'}>],
#        [<Axes: title={'center': 'Parch'}>,
#         <Axes: title={'center': 'Fare'}>,
#         <Axes: title={'center': 'Embarked'}>, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
df_test.hist(figsize=(10,10), layout=(3,2))
# Out:
# array([[<Axes: title={'center': 'Pclass'}>,
#         <Axes: title={'center': 'Sex'}>],
#        [<Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Embarked'}>, <Axes: >]], dtype=object)

# %%
import seaborn as sns

# %%
z=df_train.corr(numeric_only=True)
z
# Out:
#           Survived    Pclass       Sex     SibSp     Parch      Fare  Embarked
# Survived  1.000000 -0.338481  0.543351 -0.035322  0.081629  0.257307  0.108669
# Pclass   -0.338481  1.000000 -0.131900  0.083081  0.018443 -0.549500  0.043835
# Sex       0.543351 -0.131900  1.000000  0.114631  0.245489  0.182333  0.118593
# SibSp    -0.035322  0.083081  0.114631  1.000000  0.414838  0.159651 -0.060606
# Parch     0.081629  0.018443  0.245489  0.414838  1.000000  0.216225 -0.079320
# Fare      0.257307 -0.549500  0.182333  0.159651  0.216225  1.000000  0.063462
# Embarked  0.108669  0.043835  0.118593 -0.060606 -0.079320  0.063462  1.000000

# %%
k=df_test.corr(numeric_only=True)
k
# Out:
#             Pclass       Sex     SibSp     Parch  Embarked
# Pclass    1.000000 -0.108615  0.001087  0.018721  0.031096
# Sex      -0.108615  1.000000  0.099943  0.159120  0.126779
# SibSp     0.001087  0.099943  1.000000  0.306895 -0.100603
# Parch     0.018721  0.159120  0.306895  1.000000 -0.125164
# Embarked  0.031096  0.126779 -0.100603 -0.125164  1.000000

# %%
sns.heatmap(z,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(k,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df_train)

# %%
sns.pairplot(df_test)

# %%
df_train.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
# prompt: combine df_train and df_test as df

df = pd.concat([df_train, df_test], ignore_index=True)
df
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0          0.0       3    0  22.0      1      0     7.25       0.0
# 1          1.0       1    1  38.0      1      0  71.2833       1.0
# 2          1.0       3    1  26.0      0      0    7.925       0.0
# 3          1.0       1    1  35.0      1      0     53.1       0.0
# 4          0.0       3    0  35.0      0      0     8.05       0.0
# ...        ...     ...  ...   ...    ...    ...      ...       ...
# 1304       NaN       3    0    NA      0      0     8.05       0.0
# 1305       NaN       1    1  39.0      0      0    108.9       1.0
# 1306       NaN       3    0  38.5      0      0     7.25       0.0
# 1307       NaN       3    0    NA      0      0     8.05       0.0
# 1308       NaN       3    0    NA      1      1  22.3583       1.0
#
# [1309 rows x 8 columns]

# %%
df.shape
# Out:
# (1309, 8)

# %%
# Out:
# Survived    418
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df.fillna('N',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-144-243188276.py in <cell line: 0>()
# ----> 1 df.fillna(Na,inplace=True)
#
# NameError: name 'Na' is not defined

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
x=df.drop(['Survived'],axis=1)
x
# Out:
#       Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0          3    0  22.0      1      0     7.25      0.0
# 1          1    1  38.0      1      0  71.2833      1.0
# 2          3    1  26.0      0      0    7.925      0.0
# 3          1    1  35.0      1      0     53.1      0.0
# 4          3    0  35.0      0      0     8.05      0.0
# ...      ...  ...   ...    ...    ...      ...      ...
# 1304       3    0    NA      0      0     8.05      0.0
# 1305       1    1  39.0      0      0    108.9      1.0
# 1306       3    0  38.5      0      0     7.25      0.0
# 1307       3    0    NA      0      0     8.05      0.0
# 1308       3    0    NA      1      1  22.3583      1.0
#
# [1309 rows x 7 columns]

# %%
y=df.Survived

# %%
y
# Out:
# 0       0.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0
#        ...
# 1304     NA
# 1305     NA
# 1306     NA
# 1307     NA
# 1308     NA
# Name: Survived, Length: 1309, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (916, 7)
# (393, 7)
# (916,)
# (393,)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-142-1002171229.py in <cell line: 0>()
# ----> 1 model.fit(x_train,y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   object
#  1   Pclass    1309 non-null   int64
#  2   Sex       1309 non-null   int64
#  3   Age       1309 non-null   object
#  4   SibSp     1309 non-null   int64
#  5   Parch     1309 non-null   int64
#  6   Fare      1309 non-null   object
#  7   Embarked  1309 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 81.9+ KB
